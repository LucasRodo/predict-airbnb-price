# %% [markdown]
# # Imports & Data

# %%
import pandas as pd
import numpy as np
import geopandas

# %% [markdown]
# ### Data

# %%
data_d = pd.read_csv('data/Airbnb_Mx_December.csv.gz')
data_s = pd.read_csv('data/Airbnb_Mx_September.csv.gz')
data_d.head(2)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  35797  https://www.airbnb.com/rooms/35797  20211225071008   2021-12-26
# 1  44616  https://www.airbnb.com/rooms/44616  20211225071008   2021-12-25
#
#                 name                                        description  \
# 0        Villa Dante  Dentro de Villa un estudio de arte con futon, ...
# 1  CONDESA HAUS  B&B  A new concept of hosting in mexico through a b...
#
#                                neighborhood_overview  \
# 0  Centro comercial Santa Fe, parque interlomas y...
# 1                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f395ab78-1185...   153786
# 1  https://a0.muscache.com/pictures/251410/ec75fe...   196253
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/153786  ...                         NaN
# 1  https://www.airbnb.com/users/show/196253  ...                        4.76
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                    NaN                 NaN     NaN                f
# 1                   4.98                4.45     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                             10                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0              0.41
#
# [2 rows x 74 columns]

# %%
data_s.head(2)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  35797  https://www.airbnb.com/rooms/35797  20210928184726   2021-09-30
# 1  44616  https://www.airbnb.com/rooms/44616  20210928184726   2021-09-29
#
#                 name                                        description  \
# 0        Villa Dante  Dentro de Villa un estudio de arte con futon, ...
# 1  CONDESA HAUS  B&B  A new concept of hosting in mexico through a b...
#
#                                neighborhood_overview  \
# 0  Centro comercial Santa Fe, parque interlomas y...
# 1                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f395ab78-1185...   153786
# 1  https://a0.muscache.com/pictures/251410/ec75fe...   196253
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/153786  ...                         NaN
# 1  https://www.airbnb.com/users/show/196253  ...                        4.76
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                    NaN                 NaN     NaN                f
# 1                   4.98                4.45     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                             10                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0              4.26
#
# [2 rows x 74 columns]

# %% [markdown]
# #### Sum DataFrames

# %%
frames = [data_d, data_s]
  
data = pd.concat(frames)
data.head(2)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  35797  https://www.airbnb.com/rooms/35797  20211225071008   2021-12-26
# 1  44616  https://www.airbnb.com/rooms/44616  20211225071008   2021-12-25
#
#                 name                                        description  \
# 0        Villa Dante  Dentro de Villa un estudio de arte con futon, ...
# 1  CONDESA HAUS  B&B  A new concept of hosting in mexico through a b...
#
#                                neighborhood_overview  \
# 0  Centro comercial Santa Fe, parque interlomas y...
# 1                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f395ab78-1185...   153786
# 1  https://a0.muscache.com/pictures/251410/ec75fe...   196253
#
#                                    host_url  ... review_scores_communication  \
# 0  https://www.airbnb.com/users/show/153786  ...                         NaN
# 1  https://www.airbnb.com/users/show/196253  ...                        4.76
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                    NaN                 NaN     NaN                f
# 1                   4.98                4.45     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                             10                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0              0.41
#
# [2 rows x 74 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38818 entries, 0 to 19162
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            38818 non-null  int64
#  1   listing_url                                   38818 non-null  object
#  2   scrape_id                                     38818 non-null  int64
#  3   last_scraped                                  38818 non-null  object
#  4   name                                          38812 non-null  object
#  5   description                                   36451 non-null  object
#  6   neighborhood_overview                         25788 non-null  object
#  7   picture_url                                   38818 non-null  object
#  8   host_id                                       38818 non-null  int64
#  9   host_url                                      38818 non-null  object
#  10  host_name                                     38813 non-null  object
#  11  host_since                                    38813 non-null  object
#  12  host_location                                 38729 non-null  object
#  13  host_about                                    22099 non-null  object
#  14  host_response_time                            31509 non-null  object
#  15  host_response_rate                            31509 non-null  object
#  16  host_acceptance_rate                          30816 non-null  object
#  17  host_is_superhost                             38813 non-null  object
#  18  host_thumbnail_url                            38813 non-null  object
#  19  host_picture_url                              38813 non-null  object
#  20  host_neighbourhood                            19776 non-null  object
#  21  host_listings_count                           38813 non-null  float64
#  22  host_total_listings_count                     38813 non-null  float64
#  23  host_verifications                            38818 non-null  object
#  24  host_has_profile_pic                          38813 non-null  object
#  25  host_identity_verified                        38813 non-null  object
#  26  neighbourhood                                 25788 non-null  object
#  27  neighbourhood_cleansed                        38818 non-null  object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      38818 non-null  float64
#  30  longitude                                     38818 non-null  float64
#  31  property_type                                 38818 non-null  object
#  32  room_type                                     38818 non-null  object
#  33  accommodates                                  38818 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                38727 non-null  object
#  36  bedrooms                                      37391 non-null  float64
#  37  beds                                          37965 non-null  float64
#  38  amenities                                     38818 non-null  object
#  39  price                                         38818 non-null  object
#  40  minimum_nights                                38818 non-null  int64
#  41  maximum_nights                                38818 non-null  int64
#  42  minimum_minimum_nights                        38817 non-null  float64
#  43  maximum_minimum_nights                        38817 non-null  float64
#  44  minimum_maximum_nights                        38817 non-null  float64
#  45  maximum_maximum_nights                        38817 non-null  float64
#  46  minimum_nights_avg_ntm                        38817 non-null  float64
#  47  maximum_nights_avg_ntm                        38817 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              38818 non-null  object
#  50  availability_30                               38818 non-null  int64
#  51  availability_60                               38818 non-null  int64
#  52  availability_90                               38818 non-null  int64
#  53  availability_365                              38818 non-null  int64
#  54  calendar_last_scraped                         38818 non-null  object
#  55  number_of_reviews                             38818 non-null  int64
#  56  number_of_reviews_ltm                         38818 non-null  int64
#  57  number_of_reviews_l30d                        38818 non-null  int64
#  58  first_review                                  30324 non-null  object
#  59  last_review                                   30324 non-null  object
#  60  review_scores_rating                          30324 non-null  float64
#  61  review_scores_accuracy                        30072 non-null  float64
#  62  review_scores_cleanliness                     30072 non-null  float64
#  63  review_scores_checkin                         30069 non-null  float64
#  64  review_scores_communication                   30072 non-null  float64
#  65  review_scores_location                        30067 non-null  float64
#  66  review_scores_value                           30068 non-null  float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              38818 non-null  object
#  69  calculated_host_listings_count                38818 non-null  int64
#  70  calculated_host_listings_count_entire_homes   38818 non-null  int64
#  71  calculated_host_listings_count_private_rooms  38818 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   38818 non-null  int64
#  73  reviews_per_month                             30324 non-null  float64
# dtypes: float64(24), int64(17), object(33)
# memory usage: 22.2+ MB

# %%
(data[['neighbourhood_group_cleansed','bathrooms', 'calendar_updated','license']]).head(4)
# Out:
#    neighbourhood_group_cleansed  bathrooms  calendar_updated  license
# 0                           NaN        NaN               NaN      NaN
# 1                           NaN        NaN               NaN      NaN
# 2                           NaN        NaN               NaN      NaN
# 3                           NaN        NaN               NaN      NaN

# %%
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# For the next step, we'll remove a lot of the unnecessary columns, as they just take up space and I don't think they're useful for the model.

# %%
# columns we are going to drop
col= ['listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
       'amenities', 'picture_url', 'host_id', 'host_url',
       'host_name', 'host_since', 'host_location', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
       'host_neighbourhood', 'host_listings_count', 'neighborhood_overview',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified',
       'neighbourhood', 'neighbourhood_group_cleansed','bathrooms',
       'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
       'availability_30', 'availability_60', 'availability_90',
       'availability_365', 'calendar_last_scraped',
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'license', 'instant_bookable',
       'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
df_airbnb = data.drop(col, axis=1)
df_airbnb.head(4)
# Out:
#       id neighbourhood_cleansed  latitude  longitude  \
# 0  35797  Cuajimalpa de Morelos  19.38283  -99.27178
# 1  44616             Cuauhtémoc  19.41162  -99.17794
# 2  56074             Cuauhtémoc  19.43977  -99.15605
# 3  61792             Cuauhtémoc  19.41083  -99.18057
#
#                       property_type        room_type  accommodates  \
# 0                      Entire villa  Entire home/apt             2
# 1           Entire residential home  Entire home/apt            14
# 2        Entire condominium (condo)  Entire home/apt             2
# 3  Private room in residential home     Private room             2
#
#    bathrooms_text  bedrooms  beds       price  number_of_reviews
# 0          1 bath       1.0   1.0   $4,123.00                  0
# 1       5.5 baths       5.0   8.0  $15,000.00                 50
# 2          1 bath       1.0   1.0     $600.00                 66
# 3  1 private bath       1.0   1.0   $1,237.00                 53

# %% [markdown]
# In the dataframe, the bathroom column is empty, so we only have the bathroom s_text column, which we will convert to a more manageable format.

# %%
df_airbnb['bathrooms_text'] = df_airbnb['bathrooms_text'].str.extract("(\d*\.?\d+)", expand=True).astype('float')
df_airbnb.rename(columns = {'bathrooms_text':'bathrooms'}, inplace = True)
df_airbnb.head(10)
# Out:
#        id neighbourhood_cleansed  latitude  longitude  \
# 0   35797  Cuajimalpa de Morelos  19.38283  -99.27178
# 1   44616             Cuauhtémoc  19.41162  -99.17794
# 2   56074             Cuauhtémoc  19.43977  -99.15605
# 3   61792             Cuauhtémoc  19.41083  -99.18057
# 4   67703             Cuauhtémoc  19.41152  -99.16857
# 5   70644               Coyoacán  19.35448  -99.16217
# 6  107078         Miguel Hidalgo  19.43211  -99.19327
# 7  131610               Coyoacán  19.35416  -99.16488
# 8  165772         Miguel Hidalgo  19.40826  -99.18659
# 9  171109          Benito Juárez  19.39675  -99.17581
#
#                       property_type        room_type  accommodates  bathrooms  \
# 0                      Entire villa  Entire home/apt             2        1.0
# 1           Entire residential home  Entire home/apt            14        5.5
# 2        Entire condominium (condo)  Entire home/apt             2        1.0
# 3  Private room in residential home     Private room             2        1.0
# 4                Entire rental unit  Entire home/apt             4        1.0
# 5                Entire rental unit  Entire home/apt             2        1.0
# 6                       Entire loft  Entire home/apt             2        1.5
# 7                      Private room     Private room             2        1.0
# 8           Entire residential home  Entire home/apt            14        4.5
# 9       Private room in rental unit     Private room             2        1.0
#
#    bedrooms  beds       price  number_of_reviews
# 0       1.0   1.0   $4,123.00                  0
# 1       5.0   8.0  $15,000.00                 50
# 2       1.0   1.0     $600.00                 66
# 3       1.0   1.0   $1,237.00                 53
# 4       2.0   3.0   $1,959.00                 39
# 5       1.0   1.0   $1,606.00                106
# 6       1.0   1.0   $3,878.00                 10
# 7       1.0   1.0   $1,403.00                  0
# 8       4.0   9.0   $4,125.00                273
# 9       1.0   1.0     $299.00                 76

# %% [markdown]
# We remove the $ symbol from the price column

# %%
df_airbnb['price'] = df_airbnb['price'].str.replace(r"[\$\,]", "").astype(float).round().astype(int)
df_airbnb.head(10)
# Out:
# C:\Users\skele\AppData\Local\Temp/ipykernel_17588/3758861431.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_airbnb['price'] = df_airbnb['price'].str.replace(r"[\$\,]", "").astype(float).round().astype(int)
#        id neighbourhood_cleansed  latitude  longitude  \
# 0   35797  Cuajimalpa de Morelos  19.38283  -99.27178
# 1   44616             Cuauhtémoc  19.41162  -99.17794
# 2   56074             Cuauhtémoc  19.43977  -99.15605
# 3   61792             Cuauhtémoc  19.41083  -99.18057
# 4   67703             Cuauhtémoc  19.41152  -99.16857
# 5   70644               Coyoacán  19.35448  -99.16217
# 6  107078         Miguel Hidalgo  19.43211  -99.19327
# 7  131610               Coyoacán  19.35416  -99.16488
# 8  165772         Miguel Hidalgo  19.40826  -99.18659
# 9  171109          Benito Juárez  19.39675  -99.17581
#
#                       property_type        room_type  accommodates  bathrooms  \
# 0                      Entire villa  Entire home/apt             2        1.0
# 1           Entire residential home  Entire home/apt            14        5.5
# 2        Entire condominium (condo)  Entire home/apt             2        1.0
# 3  Private room in residential home     Private room             2        1.0
# 4                Entire rental unit  Entire home/apt             4        1.0
# 5                Entire rental unit  Entire home/apt             2        1.0
# 6                       Entire loft  Entire home/apt             2        1.5
# 7                      Private room     Private room             2        1.0
# 8           Entire residential home  Entire home/apt            14        4.5
# 9       Private room in rental unit     Private room             2        1.0
#
#    bedrooms  beds  price  number_of_reviews
# 0       1.0   1.0   4123                  0
# 1       5.0   8.0  15000                 50
# 2       1.0   1.0    600                 66
# 3       1.0   1.0   1237                 53
# 4       2.0   3.0   1959                 39
# 5       1.0   1.0   1606                106
# 6       1.0   1.0   3878                 10
# 7       1.0   1.0   1403                  0
# 8       4.0   9.0   4125                273
# 9       1.0   1.0    299                 76

# %% [markdown]
# ##

# %%
airbnb = geopandas.GeoDataFrame(df_airbnb,
           geometry=geopandas.points_from_xy(
           df_airbnb.longitude, df_airbnb.latitude))

airbnb.head(8)
# Out:
#        id neighbourhood_cleansed  latitude  longitude  \
# 0   35797  Cuajimalpa de Morelos  19.38283  -99.27178
# 1   44616             Cuauhtémoc  19.41162  -99.17794
# 2   56074             Cuauhtémoc  19.43977  -99.15605
# 3   61792             Cuauhtémoc  19.41083  -99.18057
# 4   67703             Cuauhtémoc  19.41152  -99.16857
# 5   70644               Coyoacán  19.35448  -99.16217
# 6  107078         Miguel Hidalgo  19.43211  -99.19327
# 7  131610               Coyoacán  19.35416  -99.16488
#
#                       property_type        room_type  accommodates  bathrooms  \
# 0                      Entire villa  Entire home/apt             2        1.0
# 1           Entire residential home  Entire home/apt            14        5.5
# 2        Entire condominium (condo)  Entire home/apt             2        1.0
# 3  Private room in residential home     Private room             2        1.0
# 4                Entire rental unit  Entire home/apt             4        1.0
# 5                Entire rental unit  Entire home/apt             2        1.0
# 6                       Entire loft  Entire home/apt             2        1.5
# 7                      Private room     Private room             2        1.0
#
#    bedrooms  beds  price  number_of_reviews                    geometry
# 0       1.0   1.0   4123                  0  POINT (-99.27178 19.38283)
# 1       5.0   8.0  15000                 50  POINT (-99.17794 19.41162)
# 2       1.0   1.0    600                 66  POINT (-99.15605 19.43977)
# 3       1.0   1.0   1237                 53  POINT (-99.18057 19.41083)
# 4       2.0   3.0   1959                 39  POINT (-99.16857 19.41152)
# 5       1.0   1.0   1606                106  POINT (-99.16217 19.35448)
# 6       1.0   1.0   3878                 10  POINT (-99.19327 19.43211)
# 7       1.0   1.0   1403                  0  POINT (-99.16488 19.35416)

# %%
airbnb = airbnb.drop(['latitude','longitude'], axis=1)
airbnb.columns
# Out:
# Index(['id', 'neighbourhood_cleansed', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'price',
#        'number_of_reviews', 'geometry'],
#       dtype='object')

# %%
airbnb.head()
# Out:
#       id neighbourhood_cleansed                     property_type  \
# 0  35797  Cuajimalpa de Morelos                      Entire villa
# 1  44616             Cuauhtémoc           Entire residential home
# 2  56074             Cuauhtémoc        Entire condominium (condo)
# 3  61792             Cuauhtémoc  Private room in residential home
# 4  67703             Cuauhtémoc                Entire rental unit
#
#          room_type  accommodates  bathrooms  bedrooms  beds  price  \
# 0  Entire home/apt             2        1.0       1.0   1.0   4123
# 1  Entire home/apt            14        5.5       5.0   8.0  15000
# 2  Entire home/apt             2        1.0       1.0   1.0    600
# 3     Private room             2        1.0       1.0   1.0   1237
# 4  Entire home/apt             4        1.0       2.0   3.0   1959
#
#    number_of_reviews                    geometry
# 0                  0  POINT (-99.27178 19.38283)
# 1                 50  POINT (-99.17794 19.41162)
# 2                 66  POINT (-99.15605 19.43977)
# 3                 53  POINT (-99.18057 19.41083)
# 4                 39  POINT (-99.16857 19.41152)

# %%
airbnb_2 = airbnb.drop(["property_type","room_type","neighbourhood_cleansed"], axis=1)

# %%
airbnb_2.isna().sum()
# Out:
# id                      0
# accommodates            0
# bathrooms             143
# bedrooms             1427
# beds                  853
# price                   0
# number_of_reviews       0
# geometry                0
# dtype: int64

# %%
airbnb_2.dropna(subset=["bathrooms","bedrooms","beds"],inplace=True)

# %%
airbnb_2.isna().sum()
# Out:
# id                   0
# accommodates         0
# bathrooms            0
# bedrooms             0
# beds                 0
# price                0
# number_of_reviews    0
# geometry             0
# dtype: int64

# %% [markdown]
# # Model

# %%
from sklearn.model_selection import train_test_split


X = airbnb_2.drop(columns=["id", "price","geometry"])
y = airbnb_2["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                   test_size=0.20, random_state=97)

# %%
from sklearn.linear_model import LinearRegression

Train_model = LinearRegression()
Train_model.fit(X_train, y_train)

R_2 = Train_model.score(X_train, y_train)
R_2
# Out:
# 0.05482022007822507

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

cur_one_hot = OneHotEncoder(categories="auto")
cur_pipeline = Pipeline([
    ("one_hot", cur_one_hot),
    ("lin_reg", LinearRegression())
])

cur_pipeline.fit(X_train, y_train)
R_2 = cur_pipeline.score(X_train, y_train)
R_2
# Out:
# 0.1425741769061175

# %% [markdown]
# The model is pretty bad XD, it's a future project
